# %% [markdown]
# # Thai Authentic Supermarket on-line in Toronto Proporsal Project (Part2)

# %% [markdown]
# ## This is another Coursera Capstone Project- Part of IBM data science course.

# %% [markdown]
# ### ## Answer1 for assignment
#
# _A description of the problem and a discussion of the background._
#
# Initial Observation via websites
# In this project, I will show you what I have discovered and I will explain why it is a good idea to run Thai Authentic on-line market in Toronto. I also gather some information for the most popular thai dishes and which ingredients should be sold easily. Also, the competitive price you should target for.
#
# From wikipedia website,click Thai_Canadians, census 2016, saying that there are 19,010 thai canadians by ancestry in Canada. Census 1991 shows that there were 5820 immigrants who were born in Thailand. Also, there were more women than men. Cities where many thai people live are Ontario, British Columbia, Quebec and Alberta.
#
# Thai food is very popular in Toronto. Searching by google, there are more than 100 thai restaurants in this area. Also, there are more than 50 chinese supermarkets. However, no record about Thai supermarket at all! I believe they're existed, but not many. I also found many people complaining that they want to cook at home and they cannot find some items or not so fresh. Therefore, this is an amazing opportunity for running a Thai Market on-line business in Toronto. On-line seems to be a good option so you can save your budgets and buying on-line is very trendy nowadays. To be more competitive, the price should be lower than those chinese supermarkets.
#
# I already have Toronto Data from my previous capstone project. Please have a look first.
#
# Many Thanks for your visit.

# %% [markdown]
# My plans are:
#
# - gathering data from different websites to get the insight understanding.
# - using Foursquare API to find the geographical location.
# - using folium to show the map.
# - using some statistical approach such as K-Means clustering
# - Showing some popular dishes and their ingredients so you can plan to shape your business.

# %% [markdown]
# ### At a glance, here are those popular thai restaurants in Toronto.

# %%
#From foursquare.com, there are 90 restaurants.
from PIL import Image
path = "thairestaurant.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=606x482 at 0x7FB51930A590>

# %% [markdown]
# ### Here are Chinese or Asian Supermarkets

# %%
#Picture from google.com
from PIL import Image
path = "chinesesupermarket.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=709x490 at 0x7FB51864A910>

# %% [markdown]
# Statistics Canada, Census Profile, 2016 census- Toronto, Ontario, Canada
# https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/prof/details/page.cfm?Lang=E&Geo1=POPC&Code1=0944&Geo2=PR&Code2=01&Data=Count&SearchText=toronto&SearchType=Begins&SearchPR=01&B1=All&TABID=1
# From this website, I found that there are more thai women than men for both Canada population data and Toronto population data.

# %%
#thai population in Toronto, 2016 census
import pandas as pd
# intialise data of lists.
data = {'type':['motherTongue','ethnicOrigin'],
        'male':[475, 1225],
         'female':[1080, 2010]}
df = pd.DataFrame(data)
print(df)
# Out:
#            type  male  female
# 0  motherTongue   475    1080
# 1  ethnicOrigin  1225    2010

# %%
#thai population in Canada, 2016 census
import pandas as np
# intialise data of lists.
data2 = {'type':['motherTongue','ethnicOrigin'],
        'male':[2690, 7330],
         'female':[6565, 11680]}
df2 = pd.DataFrame(data2)
print(df2)
# Out:
#            type  male  female
# 0  motherTongue  2690    6565
# 1  ethnicOrigin  7330   11680

# %% [markdown]
# ## Answer2 for assignment

# %% [markdown]
# _A description of the data and how it will be used to solve the problem_
#
# From above, I have already explained about description of the data from different websites.
#
# My plans are:
#
# -gathering data from different websites to get the insight understanding.
# -using Foursquare API to find the geographical location.
# -using folium to show the map.
# -using some statistical approach such as K-Means clustering
# -Showing some popular dishes and their ingredients so you can plan to shape your business.
